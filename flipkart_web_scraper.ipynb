# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
def get_title(soup):

    try:
        
        title = soup.find("span", attrs={"class":'B_NuCI'})
        
        
        title_value = title.text

        
        title_string = title_value.strip()

    except AttributeError:
        title_string = ""

    return title_string


def get_price(soup):

    try:
        price = soup.find("div", attrs={"class":'_30jeq3 _16Jk6d'}).string
        
        price_value=price.text

    except AttributeError:
        price_value = ""

    return price_value


def get_rating(soup):

    try:
        rating = soup.find("div", attrs={"class":'_2d4LTz'}).string
        
    except:
        rating = ""

    return rating



def get_discount(soup):
    try:
        discount = soup.find("div", attrs={"class":'_1V_ZGU'}).string
    except AttributeError:
        discount = ""
    return discount

# %%
if __name__ == '__main__':

    
    HEADERS = ({'User-Agent':'', 'Accept-Language': 'en-US, en;q=0.5'})

    
    URL = "https://www.flipkart.com/search?q=mobiles&as=on&as-show=on&otracker=AS_Query_TrendingAutoSuggest_1_0_na_na_na&otracker1=AS_Query_TrendingAutoSuggest_1_0_na_na_na&as-pos=1&as-type=TRENDING&suggestionId=mobiles&requestId=04f31658-7ad8-40ea-8b73-6bfd3e4059b2"

    
    webpage = requests.get(URL, headers=HEADERS)

    
    soup = BeautifulSoup(webpage.content, "html.parser")

    
    links = soup.find_all("a", attrs={'class':'_1fQZEK'})

    
    links_list = []

    
    for link in links:
            links_list.append(link.get('href'))

    d = {"title":[], "price":[], "rating":[],"discount":[]}
    
     
    for link in links_list:
        new_webpage = requests.get("https://www.flipkart.com" + link, headers=HEADERS)

        new_soup = BeautifulSoup(new_webpage.content, "html.parser")

        
        d['title'].append(get_title(new_soup))
        d['price'].append(get_price(new_soup))
        d['rating'].append(get_rating(new_soup))
        d['discount'].append(get_discount(new_soup))

    
    flipkart_df = pd.DataFrame.from_dict(d)
    flipkart_df['title'].replace('', np.nan, inplace=True)
    flipkart_df = flipkart_df.dropna(subset=['title'])
    flipkart_df.to_csv("flipkart_data.csv", header=True, index=False)

# %%
flipkart_df
# Out:
#                                                 title    price rating  \
# 0   Motorola G34 5G (Ocean Green, 128 GB)  (8 GB RAM)  ₹11,999    4.2
# 1   Motorola G34 5G (Charcoal Black, 128 GB)  (8 G...  ₹11,999    4.2
# 2   POCO C51 - Locked with Airtel Prepaid (Royal B...   ₹4,999      4
# 3      Motorola G34 5G (Ice Blue, 128 GB)  (8 GB RAM)  ₹11,999    4.2
# 4                      Apple iPhone 14 (Blue, 128 GB)  ₹54,999    4.6
# 5      realme C53 (Champion Gold, 128 GB)  (6 GB RAM)   ₹9,199    4.4
# 6     realme C53 (Champion Black, 128 GB)  (6 GB RAM)   ₹9,199    4.4
# 7   POCO C51 - Locked with Airtel Prepaid (Power B...   ₹4,999      4
# 8      realme C53 (Champion Black, 64 GB)  (6 GB RAM)   ₹7,499    4.4
# 10  POCO M6 Pro 5G (Forest Green, 128 GB)  (6 GB RAM)  ₹10,999    4.3
# 11          POCO C55 (Power Black, 64 GB)  (4 GB RAM)   ₹5,999    4.2
# 12        MOTOROLA G04 (Sea Green, 64 GB)  (4 GB RAM)   ₹6,999    4.2
# 13     REDMI 13C (Stardust Black, 128 GB)  (4 GB RAM)   ₹7,799    4.3
# 14  vivo T2x 5G (Sunstone Orange, 128 GB)  (4 GB RAM)  ₹13,780    4.4
# 15  MOTOROLA g24 Power (Ink blue, 128 GB)  (8 GB RAM)   ₹8,999    4.2
# 16  OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 256...  ₹19,797    4.4
# 17  OnePlus Nord CE 3 Lite 5G (Pastel Lime, 128 GB...  ₹17,394    4.4
# 18  OnePlus Nord CE 3 Lite 5G (Pastel Lime, 256 GB...  ₹19,398    4.4
# 19   POCO M6 Pro 5G (Power Black, 128 GB)  (6 GB RAM)  ₹10,999    4.3
# 20            REDMI A2 (Sea Green, 64 GB)  (2 GB RAM)   ₹5,299    4.2
# 21  vivo T2x 5G (Sunstone Orange, 128 GB)  (6 GB RAM)  ₹12,999    4.4
# 22    vivo T2x 5G (Glimmer Black, 128 GB)  (6 GB RAM)  ₹12,999    4.4
# 23      vivo T2x 5G (Aurora Gold, 128 GB)  (6 GB RAM)  ₹12,999    4.4
#
#             discount
# 0    Extra ₹3000 off
# 1    Extra ₹3000 off
# 2    Extra ₹5000 off
# 3    Extra ₹3000 off
# 4   Extra ₹14901 off
# 5    Extra ₹4800 off
# 6    Extra ₹4800 off
# 7    Extra ₹5000 off
# 8    Extra ₹5500 off
# 10   Extra ₹6000 off
# 11   Extra ₹6000 off
# 12   Extra ₹3000 off
# 13   Extra ₹4200 off
# 14   Extra ₹1220 off
# 15   Extra ₹4000 off
# 16   Extra ₹1769 off
# 17   Extra ₹1565 off
# 18   Extra ₹1901 off
# 19   Extra ₹6000 off
# 20   Extra ₹4700 off
# 21   Extra ₹6000 off
# 22   Extra ₹6000 off
# 23   Extra ₹6000 off
